# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from warnings import filterwarnings
filterwarnings('ignore')

# %%
import sys
sys.path.append('../')

from utils.analyse_results import *
from utils.figures import *

# %% [markdown]
# # Linkage - Texas Large (2013-2014)

# %% [markdown]
# ## Comparison with PrivBay DP

# %%
dirname = '../outputs/linkage/sdgym_eval/PrivBayFixed/'
linkage_gain = load_results_linkage(dirname)

# %%
models = ['PrivBayesEps1.0', 'PrivBayesEps10.0', 'PrivBaySDGymEps1.0', 'PrivBaySDGymEps10.0']
fig = plt_privacy_gain(linkage_gain, models)

# %% [markdown]
# ## Comparison with PrivBay Not DP

# %%
dirname = '../outputs/linkage/sdgym_eval/PrivBayNotFixed/'
linkage_gain = load_results_linkage(dirname)

# %%
models = ['PrivBayesEps1.0', 'PrivBayesEps10.0', 'PrivBaySDGymEps1.0', 'PrivBaySDGymEps10.0']
fig = plt_privacy_gain(linkage_gain, models)

# %%
dirname = '../outputs/linkage/sdgym_eval/PrivBayNotFixed_short/'
linkage_gain = load_results_linkage(dirname)

# %%
models = ['PrivBayesEps1.0', 'PrivBayesEps10.0', 'PrivBaySDGymEps1.0', 'PrivBaySDGymEps10.0']
fig = plt_privacy_gain(linkage_gain, models)
